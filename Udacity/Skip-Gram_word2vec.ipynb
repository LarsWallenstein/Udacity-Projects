# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
# !pip install utils
# Out:
# Collecting utils
#   Downloading https://files.pythonhosted.org/packages/9b/de/9ffaf89be661b32d1e0cff05e1af5e4fc2d608c47498975e94aca219aed4/utils-0.9.0-py2.py3-none-any.whl
# Installing collected packages: utils
# Successfully installed utils-0.9.0

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = '/content/drive/My Drive/embeddings/data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('/content/drive/My Drive/embeddings/data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
import re
from collections import Counter



def preprocess(text):
    # Replace punctuation with tokens so we can use them in our model
    text = text.lower()
    text = text.replace('.', ' <PERIOD> ')
    text = text.replace(',', ' <COMMA> ')
    text = text.replace('"', ' <QUOTATION_MARK> ')
    text = text.replace(';', ' <SEMICOLON> ')
    text = text.replace('!', ' <EXCLAMATION_MARK> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    text = text.replace('(', ' <LEFT_PAREN> ')
    text = text.replace(')', ' <RIGHT_PAREN> ')
    text = text.replace('--', ' <HYPHENS> ')
    text = text.replace('?', ' <QUESTION_MARK> ')
    # text = text.replace('\n', ' <NEW_LINE> ')
    text = text.replace(':', ' <COLON> ')
    words = text.split()
    
    # Remove all words with  5 or fewer occurences
    word_counts = Counter(words)
    trimmed_words = [word for word in words if word_counts[word] > 5]

    return trimmed_words

def get_batches(int_text, batch_size, seq_length):
    """
    Return batches of input and target
    :param int_text: Text with the words replaced by their ids
    :param batch_size: The size of batch
    :param seq_length: The length of sequence
    :return: A list where each item is a tuple of (batch of input, batch of target).
    """
    n_batches = int(len(int_text) / (batch_size * seq_length))

    # Drop the last few characters to make only full batches
    xdata = np.array(int_text[: n_batches * batch_size * seq_length])
    ydata = np.array(int_text[1: n_batches * batch_size * seq_length + 1])

    x_batches = np.split(xdata.reshape(batch_size, -1), n_batches, 1)
    y_batches = np.split(ydata.reshape(batch_size, -1), n_batches, 1)

    return list(zip(x_batches, y_batches))


def create_lookup_tables(words):
    """
    Create lookup tables for vocabulary
    :param words: Input list of words
    :return: A tuple of dicts.  The first dict....
    """
    word_counts = Counter(words)
    sorted_vocab = sorted(word_counts, key=word_counts.get, reverse=True)
    int_to_vocab = {ii: word for ii, word in enumerate(sorted_vocab)}
    vocab_to_int = {word: ii for ii, word in int_to_vocab.items()}

    return vocab_to_int, int_to_vocab

# %%
words = preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
len(int_to_vocab)
# Out:
# 63641

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
t = 0.001
from collections import Counter as counter
kek = counter()
for word in words:
  kek[word]+=1/16680599 
kek['a']
#train_words = # The final subsampled word list
# Out:
# 0.01953604903528235

# %%
for word in set(words):
  kek[word] = 1-(t/kek[word])**(0.5)

# %%
import random
train_words = [word for word in int_words if kek[int_to_vocab[word]]<random.random()]

# %%
int_words[0]
# Out:
# 5233

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    r = np.random.randint(1,window_size+1)
    arr = []
    if(idx<r):
      for i in range(idx):
        arr.append(words[i])
    else:
      for i in range(idx-r,idx):
        arr.append(words[i])
    if(len(words)-idx-1<r):
      if(len(words)-idx-1==0):
        1+1
      else:
        for i in range(idx+1, len(words)):
          arr.append(words[i])
    else:
      for i  in range(idx+1,idx+r+1):
        arr.append(words[i])
    # Your code here
    
    
    return list(set(arr))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape = None, name='inputs')
    labels = tf.placeholder(tf.int32, shape = [None,None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  300# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.truncated_normal((n_vocab,n_embedding),mean=0,stddev=0.1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding,inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
  saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 7.0119 0.0508 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 6.8111 0.0401 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.2168 0.0405 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6909 0.0402 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.3716 0.0402 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.1886 0.0406 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.0598 0.0402 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.9491 0.0405 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.0157 0.0403 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.0016 0.0403 sec/batch
# Nearest to between: within, of, european, just, still, in, increase, and,
# Nearest to during: was, in, the, first, beginning, great, war, after,
# Nearest to see: also, its, includes, may, of, in, list, is,
# Nearest to who: made, thing, but, represents, when, attempt, them, speaking,
# Nearest to used: however, this, use, is, even, some, other, common,
# Nearest to d: seven, eight, five, b, nine, one, politician, french,
# Nearest to or: very, other, this, to, their, can, meaning, small,
# Nearest to b: seven, one, nine, d, actor, eight, five, actress,
# Nearest to running: compare, completely, covered, visited, revolt, emerged, democratic, purposes,
# Nearest to award: brought, hans, bin, surviving, product, judah, aa, reach,
# Nearest to dr: wright, census, testament, struck, raymond, vary, hans, celebrated,
# Nearest to marriage: realized, doctrine, half, until, jordan, travelling, tsar, portugal,
# Nearest to bill: guillaume, union, arthur, education, gordon, british, sam, pioneer,
# Nearest to rise: distinguish, achieved, accompanied, assumed, consent, stand, tried, satisfy,
# Nearest to notes: capital, revolution, heavily, workers, portugal, asking, turks, elsewhere,
# Nearest to grand: bce, soldier, chains, collections, male, ban, dutch, revolution,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.9264 0.0418 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.9213 0.0407 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.8778 0.0413 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.8910 0.0403 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.8727 0.0401 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.9035 0.0408 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.8009 0.0405 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.8684 0.0411 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.8045 0.0410 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.8272 0.0406 sec/batch
# Nearest to between: of, in, and, within, land, the, with, very,
# Nearest to during: war, after, was, first, in, second, became, world,
# Nearest to see: list, topics, also, includes, information, external, links, official,
# Nearest to who: he, him, but, when, his, himself, made, later,
# Nearest to used: use, common, types, some, this, usually, is, or,
# Nearest to d: politician, eight, musician, seven, writer, chemist, poet, actress,
# Nearest to or: using, other, can, very, usually, are, is, this,
# Nearest to b: poet, fran, politician, d, actor, michael, writer, statesman,
# Nearest to running: wear, compare, immediately, chance, aryan, unique, it, polite,
# Nearest to award: won, editor, silva, november, hugo, queen, eddie, eight,
# Nearest to dr: wright, wonderland, otto, michael, guillaume, johan, edward, editor,
# Nearest to marriage: knots, brown, worked, centennial, israelis, cancer, quit, entirety,
# Nearest to bill: guillaume, six, champion, seven, five, frank, nine, athlete,
# Nearest to rise: evaluation, migrations, achieved, devoted, banks, long, knighthood, course,
# Nearest to notes: lie, travels, tragedy, submission, a, bass, contributor, asking,
# Nearest to grand: samuel, bce, male, professor, soldier, miller, eight, brabant,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.7750 0.0412 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.7415 0.0404 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.7690 0.0405 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8031 0.0407 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7543 0.0407 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7458 0.0406 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7250 0.0404 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7388 0.0406 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.6174 0.0407 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7435 0.0408 sec/batch
# Nearest to between: of, and, in, within, land, from, the, areas,
# Nearest to during: after, period, war, was, in, until, second, first,
# Nearest to see: list, topics, references, includes, links, external, history, also,
# Nearest to who: he, him, whom, himself, his, them, but, later,
# Nearest to used: use, common, using, usually, uses, often, similar, form,
# Nearest to d: te, l, politician, poet, edward, o, musician, b,
# Nearest to or: using, usually, can, other, a, are, may, which,
# Nearest to b: c, j, poet, f, d, h, l, w,
# Nearest to running: enshrined, full, placed, disposition, boron, wear, creationist, single,
# Nearest to award: won, awards, hugo, footballer, hans, joe, billy, cartoonist,
# Nearest to dr: michael, edward, robert, johan, harry, wright, sarah, born,
# Nearest to marriage: mother, died, she, wife, father, young, her, daughter,
# Nearest to bill: champion, chris, diplomat, born, tony, fox, steve, director,
# Nearest to rise: course, decline, migrations, stabilized, purge, fledgling, increased, sought,
# Nearest to notes: contributor, report, page, original, updated, bart, shura, bump,
# Nearest to grand: harpercollins, soldier, chandler, perth, champion, reigned, haley, jenkins,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7029 0.0419 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7137 0.0407 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6801 0.0403 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6872 0.0404 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.6316 0.0400 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7071 0.0405 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6844 0.0405 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6942 0.0403 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6543 0.0404 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6116 0.0404 sec/batch
# Nearest to between: within, of, in, and, from, with, through, both,
# Nearest to during: period, after, in, over, first, before, war, second,
# Nearest to see: list, topics, references, links, includes, history, information, reference,
# Nearest to who: whom, him, he, himself, killed, them, married, father,
# Nearest to used: use, using, uses, usually, applied, common, often, similar,
# Nearest to d: l, p, o, b, c, te, f, j,
# Nearest to or: a, usually, and, with, are, which, may, other,
# Nearest to b: f, h, c, d, j, o, l, n,
# Nearest to running: single, run, minutes, placed, shot, top, round, off,
# Nearest to award: awards, won, joe, oscar, eric, tom, eddie, songwriter,
# Nearest to dr: michael, edward, robert, thompson, carl, hans, george, harry,
# Nearest to marriage: mother, father, she, marry, lover, wife, her, died,
# Nearest to bill: champion, steve, frank, kevin, dick, tony, anita, alan,
# Nearest to rise: migrations, course, decline, due, carolingian, hallmark, attention, bangla,
# Nearest to notes: note, reference, pages, kelvin, a, original, pictures, publishers,
# Nearest to grand: liverpool, harpercollins, perth, newspaper, das, champion, arkansas, haley,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6658 0.0417 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6954 0.0403 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6494 0.0406 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6504 0.0405 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6058 0.0403 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6666 0.0406 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.6486 0.0404 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.6517 0.0408 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.6609 0.0405 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.5965 0.0404 sec/batch
# Nearest to between: within, of, in, lands, from, the, and, ethnic,
# Nearest to during: period, after, before, lasted, saw, throughout, fought, war,
# Nearest to see: topics, list, references, includes, links, external, articles, details,
# Nearest to who: whom, him, himself, he, parents, killed, child, young,
# Nearest to used: use, uses, using, common, referred, often, refers, similar,
# Nearest to d: b, politician, chemist, physicist, composer, painter, swiss, poet,
# Nearest to or: certain, usually, either, such, a, are, may, specific,
# Nearest to b: d, poet, politician, physicist, composer, chemist, mathematician, statesman,
# Nearest to running: run, top, single, runs, minutes, track, off, shot,
# Nearest to award: awards, nomination, academy, oscar, won, nominated, best, emmy,
# Nearest to dr: michael, robert, harry, sarah, david, jones, harvey, herbert,
# Nearest to marriage: mother, wife, father, daughter, marry, she, her, died,
# Nearest to bill: champion, harry, tony, steve, mike, dick, frank, joe,
# Nearest to rise: decline, migrations, collapse, due, wealth, difficulties, course, varied,
# Nearest to notes: pages, page, collection, encyclopedia, publications, references, information, database,
# Nearest to grand: liverpool, prussia, arkansas, champion, geneva, franco, philanthropist, mie,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.5654 0.0414 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.6155 0.0404 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.5679 0.0404 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.6279 0.0405 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.6076 0.0404 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.5751 0.0407 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.6144 0.0405 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.5405 0.0406 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.6080 0.0407 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.5703 0.0406 sec/batch
# Nearest to between: within, currents, in, both, lands, of, branches, from,
# Nearest to during: period, after, saw, fought, lasted, throughout, last, before,
# Nearest to see: list, topics, references, external, links, details, includes, mailing,
# Nearest to who: whom, him, himself, personally, killed, he, child, people,
# Nearest to used: use, using, uses, common, usually, similar, simple, referred,
# Nearest to d: b, politician, chemist, physicist, painter, writer, mathematician, laureate,
# Nearest to or: usually, either, certain, a, typically, may, are, such,
# Nearest to b: d, physicist, politician, poet, mathematician, laureate, writer, chemist,
# Nearest to running: run, top, track, runs, single, off, shot, minutes,
# Nearest to award: awards, nomination, academy, grammy, oscar, won, best, nominated,
# Nearest to dr: michael, harry, herbert, robert, peter, sarah, frank, keith,
# Nearest to marriage: mother, wife, father, sister, her, brother, heir, daughter,
# Nearest to bill: tony, dick, harry, mike, champion, nixon, joe, kevin,
# Nearest to rise: decline, carolingian, difficulties, jordanes, importance, bangui, due, gained,
# Nearest to notes: pages, collection, introduction, guide, references, page, publications, biography,
# Nearest to grand: melbourne, liverpool, arkansas, pittsburgh, champion, matthias, kenney, marshall,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.5706 0.0416 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.5752 0.0399 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.5653 0.0405 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.5743 0.0405 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.5452 0.0404 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.5656 0.0404 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.5045 0.0405 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.5762 0.0403 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.5748 0.0405 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.5876 0.0403 sec/batch
# Nearest to between: within, in, currents, both, of, difference, therefore, the,
# Nearest to during: period, saw, fought, after, throughout, war, lasted, battles,
# Nearest to see: list, topics, references, links, external, details, article, includes,
# Nearest to who: whom, him, himself, killed, personally, young, parents, fellow,
# Nearest to used: use, using, uses, referred, common, commonly, usually, usage,
# Nearest to d: b, politician, physicist, chemist, fr, pierre, violinist, l,
# Nearest to or: usually, either, typically, certain, ordinary, may, person, a,
# Nearest to b: d, physicist, mathematician, botanist, politician, poet, laureate, astronomer,
# Nearest to running: run, runs, track, shot, top, sold, road, ride,
# Nearest to award: awards, oscar, grammy, nomination, best, academy, won, emmy,
# Nearest to dr: michael, sarah, harry, nancy, brian, jones, herbert, frank,
# Nearest to marriage: wife, mother, her, father, sister, marry, brother, parents,
# Nearest to bill: clinton, manager, ford, dick, bryan, nomination, ceo, carter,
# Nearest to rise: decline, due, owing, importance, fall, difficulties, increased, migrations,
# Nearest to notes: pages, publications, encyclopedia, updated, collection, introduction, online, detailed,
# Nearest to grand: liverpool, arkansas, pittsburgh, commando, louisa, kenney, champion, honneur,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.5900 0.0415 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.5506 0.0405 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.4935 0.0403 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.5770 0.0405 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.5761 0.0405 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.5297 0.0404 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.5768 0.0402 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.5597 0.0404 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.5252 0.0402 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.5663 0.0405 sec/batch
# Nearest to between: within, poland, in, both, lands, and, the, dispute,
# Nearest to during: period, saw, throughout, lasted, began, after, ended, war,
# Nearest to see: references, list, topics, history, links, external, article, details,
# Nearest to who: whom, evil, elders, him, descendants, marriage, illegitimate, himself,
# Nearest to used: use, using, uses, referred, common, usually, often, phrase,
# Nearest to d: b, te, c, f, fr, p, l, ration,
# Nearest to or: usually, person, specific, certain, either, typically, may, individual,
# Nearest to b: d, f, c, physicist, ln, n, cdot, mathematician,
# Nearest to running: run, runs, road, track, top, moving, car, shot,
# Nearest to award: awards, oscar, grammy, hugo, best, emmy, nomination, won,
# Nearest to dr: michael, harry, brian, connor, robert, dream, peter, nancy,
# Nearest to marriage: wife, daughter, father, marry, illegitimate, mother, divorce, her,
# Nearest to bill: clinton, senate, president, chairman, cabinet, executive, resign, nomination,
# Nearest to rise: decline, migrations, importance, fall, collapse, due, owing, emergence,
# Nearest to notes: pages, updated, entries, reference, guide, online, publications, collection,
# Nearest to grand: pittsburgh, liverpool, champion, slam, hesse, prestigious, bookstore, auto,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.5211 0.0416 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.4539 0.0404 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.4845 0.0404 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.5191 0.0405 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.4930 0.0400 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.4556 0.0402 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.5657 0.0407 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.4044 0.0411 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.3834 0.0403 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.3968 0.0404 sec/batch
# Nearest to between: within, poland, dispute, ushering, both, respectively, localities, difference,
# Nearest to during: lasted, saw, period, throughout, postwar, began, after, ended,
# Nearest to see: list, references, topics, history, links, article, timeline, external,
# Nearest to who: whom, illegitimate, personally, him, father, fellow, them, himself,
# Nearest to used: use, using, uses, referred, employed, common, usually, usage,
# Nearest to d: b, violinist, politician, eight, painter, one, sar, mathematician,
# Nearest to or: person, usually, specific, either, xylene, ordinary, may, omission,
# Nearest to b: d, politician, poet, violinist, mathematician, statesman, novelist, writer,
# Nearest to running: run, runs, road, ran, track, installed, train, sold,
# Nearest to award: awards, oscar, hugo, best, grammy, emmy, academy, nomination,
# Nearest to dr: michael, dream, brian, sarah, sean, peter, robert, harry,
# Nearest to marriage: wife, daughter, mother, marry, divorce, her, illegitimate, married,
# Nearest to bill: clinton, senator, president, nixon, nomination, senate, tony, chairman,
# Nearest to rise: decline, migrations, collapse, emergence, importance, owing, fall, due,
# Nearest to notes: pages, entries, imdb, publications, updated, glossary, maps, guide,
# Nearest to grand: pittsburgh, arkansas, melbourne, champion, sheffield, arlington, hesse, sherman,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 4.4390 0.0419 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 4.5118 0.0405 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 4.5351 0.0406 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 4.5007 0.0410 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.5978 0.0411 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.5850 0.0410 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.5668 0.0406 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.5409 0.0404 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.3534 0.0403 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.5285 0.0403 sec/batch
# Nearest to between: within, both, poland, difference, in, with, dispute, respectively,
# Nearest to during: lasted, saw, period, throughout, after, ended, postwar, began,
# Nearest to see: list, references, topics, links, external, here, redirects, article,
# Nearest to who: whom, elders, killed, personally, illegitimate, him, them, people,
# Nearest to used: use, using, uses, usage, acronym, usually, referred, ascii,
# Nearest to d: b, te, violinist, sar, politician, ivoire, walther, pierre,
# Nearest to or: usually, specific, either, typically, person, is, certain, sometimes,
# Nearest to b: d, politician, conductor, mathematician, f, statesman, physicist, orientalist,
# Nearest to running: run, runs, road, track, ran, train, cameras, controller,
# Nearest to award: awards, grammy, hugo, nominated, oscar, academy, best, emmy,
# Nearest to dr: michael, robert, brian, sean, keith, murray, miller, ron,
# Nearest to marriage: divorce, marry, wife, illegitimate, daughter, marriages, parents, daughters,
# Nearest to bill: clinton, nixon, president, ceo, senate, tony, presidential, chairman,
# Nearest to rise: decline, collapse, fall, migrations, emergence, owing, importance, dominance,
# Nearest to notes: pages, glossary, detailed, definitive, publications, biographical, collection, page,
# Nearest to grand: duchy, slam, duke, naples, prussia, perth, basilica, melbourne,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.4995 0.0413 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.5229 0.0401 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.4947 0.0401 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.5389 0.0406 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.5033 0.0403 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.4007 0.0403 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.3078 0.0403 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.4883 0.0403 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.4439 0.0406 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.4328 0.0405 sec/batch
# Nearest to between: within, both, difference, with, in, of, the, shingle,
# Nearest to during: lasted, period, after, saw, throughout, postwar, ended, war,
# Nearest to see: list, references, topics, external, links, history, timeline, redirects,
# Nearest to who: whom, elders, personally, him, unwilling, fellow, gifted, killed,
# Nearest to used: use, using, uses, intended, designed, referred, employed, usage,
# Nearest to d: b, politician, violinist, mathematician, writer, alexandre, poet, adventurer,
# Nearest to or: usually, typically, specific, either, generically, appropriate, ordinary, person,
# Nearest to b: d, mathematician, politician, poet, statesman, writer, astronomer, violinist,
# Nearest to running: run, runs, ran, platform, installed, processors, bus, controller,
# Nearest to award: awards, grammy, hugo, nominations, nomination, nominated, oscar, academy,
# Nearest to dr: michael, robert, keith, richard, morris, peter, alice, murray,
# Nearest to marriage: divorce, marry, marriages, wife, sexual, illegitimate, intercourse, rape,
# Nearest to bill: clinton, tony, nixon, congressman, ceo, kevin, carter, senator,
# Nearest to rise: decline, importance, emergence, collapse, fall, migrations, owing, prevailing,
# Nearest to notes: pages, updated, entries, detail, detailed, publications, maps, comprehensive,
# Nearest to grand: slam, duchy, brabant, tuscany, prix, duke, defeats, bourbon,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.5016 0.0416 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.4777 0.0403 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.4538 0.0404 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.4568 0.0405 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.5129 0.0403 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.5234 0.0406 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 4.5109 0.0173 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 4.4769 0.0404 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 4.4498 0.0406 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 4.5086 0.0405 sec/batch
# Nearest to between: within, with, difference, in, both, shingle, the, currents,
# Nearest to during: period, after, lasted, throughout, late, postwar, in, instability,
# Nearest to see: list, references, external, links, history, topics, redirects, timeline,
# Nearest to who: whom, elders, killed, whose, personally, him, assassins, illegitimate,
# Nearest to used: use, using, employed, uses, referred, intended, usage, applied,
# Nearest to d: b, politician, sar, violinist, te, mathematician, walther, inventor,
# Nearest to or: usually, either, person, specific, typically, appropriate, xylene, omission,
# Nearest to b: d, politician, mathematician, statesman, playwright, violinist, poet, mineralogist,
# Nearest to running: run, runs, ran, line, yards, platform, installed, jump,
# Nearest to award: awards, nominations, grammy, oscar, nominated, best, nomination, academy,
# Nearest to dr: michael, robert, richard, alice, peter, miller, david, campbell,
# Nearest to marriage: divorce, marriages, marry, illegitimate, wife, child, rape, sexual,
# Nearest to bill: clinton, ceo, tony, carter, nixon, congressman, senator, mike,
# Nearest to rise: decline, collapse, emergence, migrations, owing, fall, dominance, contributed,
# Nearest to notes: pages, publications, glossary, entries, collection, detailed, complete, updated,
# Nearest to grand: slam, prix, champion, duchy, pittsburgh, tuscany, aston, semifinals,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.4265 0.0416 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.4552 0.0405 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.4494 0.0403 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.3883 0.0406 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.4239 0.0405 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.4591 0.0405 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.4448 0.0407 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.4512 0.0403 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.4465 0.0406 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.4401 0.0402 sec/batch
# Nearest to between: within, both, with, difference, the, in, shingle, respectively,
# Nearest to during: lasted, after, period, throughout, instability, ended, postwar, began,
# Nearest to see: references, list, external, redirects, links, topics, history, timeline,
# Nearest to who: whom, whose, elders, baal, killed, him, illegitimate, them,
# Nearest to used: use, using, uses, applied, employed, usage, intended, referred,
# Nearest to d: b, politician, violinist, vasily, walther, mathematician, naturalist, entomologist,
# Nearest to or: usually, either, typically, specific, person, xylene, inhaled, ordinary,
# Nearest to b: d, politician, mathematician, statesman, naturalist, violinist, poet, physicist,
# Nearest to running: run, runs, ran, screen, platform, line, yards, window,
# Nearest to award: awards, nominations, nominated, oscar, grammy, academy, nomination, emmy,
# Nearest to dr: michael, robert, morris, kenneth, harold, peter, sean, griffiths,
# Nearest to marriage: divorce, marry, marriages, wife, illegitimate, daughter, married, child,
# Nearest to bill: clinton, ceo, nixon, veto, senator, owner, carter, bills,
# Nearest to rise: decline, fall, owing, rising, emergence, collapse, prevailing, migrations,
# Nearest to notes: pages, publications, biographical, bibliography, collection, searchable, almanac, definitive,
# Nearest to grand: slam, prix, duchy, tuscany, duke, brabant, dukes, oilers,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.4687 0.0418 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.4387 0.0405 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.4444 0.0404 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.3093 0.0405 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.4566 0.0404 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.4839 0.0406 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.4577 0.0408 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.4699 0.0407 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.4676 0.0404 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.4569 0.0405 sec/batch
# Nearest to between: difference, within, both, with, in, shingle, respectively, distinction,
# Nearest to during: throughout, lasted, postwar, after, period, outbreak, saw, sustained,
# Nearest to see: list, references, external, links, redirects, topics, please, history,
# Nearest to who: whom, elders, whose, baal, him, killed, gifted, odysseus,
# Nearest to used: use, employed, using, uses, applied, usage, synonym, referred,
# Nearest to d: b, politician, te, sar, violinist, walther, vasily, ter,
# Nearest to or: usually, either, person, typically, xylene, any, sometimes, properly,
# Nearest to b: d, f, politician, rightarrow, associativity, circ, injective, ab,
# Nearest to running: run, runs, ran, yards, screen, switch, straight, jumping,
# Nearest to award: awards, nominations, nominated, grammy, oscar, academy, nomination, bafta,
# Nearest to dr: michael, robert, kenneth, clark, roy, neal, harold, richard,
# Nearest to marriage: divorce, wife, marriages, marry, married, daughter, illegitimate, mother,
# Nearest to bill: ceo, clinton, mike, kevin, longtime, carter, nixon, johnson,
# Nearest to rise: decline, fall, collapse, rising, dominance, popularity, emergence, owing,
# Nearest to notes: pages, note, biographical, cyberspace, section, typography, pseudonymous, print,
# Nearest to grand: slam, prix, duchy, duke, tuscany, brabant, dukes, rapids,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.4460 0.0416 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.4543 0.0409 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.4179 0.0403 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.4142 0.0407 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.3092 0.0404 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.3213 0.0407 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.4508 0.0406 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.3898 0.0403 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.4032 0.0404 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.3969 0.0404 sec/batch
# Nearest to between: with, within, difference, both, respectively, in, electropositive, intermediate,
# Nearest to during: throughout, lasted, postwar, period, after, saw, late, aftermath,
# Nearest to see: list, references, topics, external, links, history, redirects, timeline,
# Nearest to who: whom, elders, gifted, young, whose, killed, admire, personally,
# Nearest to used: use, uses, using, applied, employed, referred, referring, coined,
# Nearest to d: te, ivoire, sar, b, ration, c, n, f,
# Nearest to or: usually, typically, either, person, xylene, specific, ordinary, any,
# Nearest to b: f, associativity, injective, satisfies, mathbb, qquad, mbox, rightarrow,
# Nearest to running: run, runs, ran, installed, road, yards, trains, line,
# Nearest to award: awards, nominations, grammy, nominated, academy, bafta, nomination, oscar,
# Nearest to dr: michael, robert, kenneth, richard, campbell, alice, murray, neal,
# Nearest to marriage: divorce, marriages, marry, wife, married, daughter, husband, mother,
# Nearest to bill: clinton, ceo, carter, kevin, mike, longtime, joe, nixon,
# Nearest to rise: decline, fall, collapse, rising, emergence, owing, dominance, recession,
# Nearest to notes: pages, note, section, glossary, detailed, publications, page, paper,
# Nearest to grand: duchy, slam, brabant, tuscany, prix, duke, dukes, naples,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.4267 0.0414 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.3631 0.0403 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.4485 0.0403 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.4330 0.0406 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.4161 0.0405 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.4110 0.0404 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.4084 0.0406 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.4454 0.0404 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.4333 0.0404 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.3781 0.0407 sec/batch
# Nearest to between: both, within, difference, with, respectively, relationship, resolve, in,
# Nearest to during: postwar, after, lasted, throughout, before, onset, saw, autumn,
# Nearest to see: list, references, topics, links, external, redirects, history, timeline,
# Nearest to who: whom, elders, whose, killed, young, fellow, him, gifted,
# Nearest to used: use, using, employed, applied, uses, referred, coined, referring,
# Nearest to d: te, ivoire, ration, b, sar, c, supp, kn,
# Nearest to or: typically, usually, either, urinate, xylene, clicks, condom, ordinary,
# Nearest to b: associativity, f, satisfies, isomorphism, injective, commutativity, modulo, rightarrow,
# Nearest to running: run, runs, ran, yards, installed, backs, platform, drivers,
# Nearest to award: awards, nominations, grammy, bafta, oscar, nomination, nominated, emmy,
# Nearest to dr: michael, dre, murray, keith, sean, robert, lucas, wilkins,
# Nearest to marriage: divorce, marriages, marry, wife, married, child, virginity, mother,
# Nearest to bill: ceo, clinton, kevin, carter, mike, hayes, pat, nixon,
# Nearest to rise: decline, fall, collapse, dominance, owing, emergence, rising, prevailing,
# Nearest to notes: note, cyberspace, pages, entries, biographical, unabridged, selections, pseudonymous,
# Nearest to grand: duchy, brabant, prix, tuscany, slam, dukes, duke, sheffield,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.4144 0.0415 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.3801 0.0404 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.4354 0.0410 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.4438 0.0405 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.4296 0.0403 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.4448 0.0406 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.3640 0.0406 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.3532 0.0404 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.3669 0.0404 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.4112 0.0409 sec/batch
# Nearest to between: both, within, difference, with, resolve, in, relationship, currents,
# Nearest to during: postwar, after, throughout, lasted, saw, before, autumn, onset,
# Nearest to see: references, list, topics, links, external, redirects, timeline, history,
# Nearest to who: whom, elders, whose, gifted, young, fellow, killed, him,
# Nearest to used: use, employed, using, uses, applied, coined, referred, abbreviated,
# Nearest to d: b, violinist, sar, te, ivoire, politician, vasily, ration,
# Nearest to or: usually, typically, any, either, xylene, omission, condom, depending,
# Nearest to b: associativity, d, f, satisfies, isomorphism, politician, injective, n,
# Nearest to running: run, runs, ran, yards, drivers, platform, backs, road,
# Nearest to award: awards, nominations, pulitzer, bafta, nominated, nomination, oscar, emmy,
# Nearest to dr: michael, seuss, dre, steven, murray, robert, mr, lucas,
# Nearest to marriage: divorce, marriages, marry, wife, daughter, married, marrying, mother,
# Nearest to bill: clinton, ceo, carter, kevin, mike, hayes, pat, congressman,
# Nearest to rise: decline, fall, collapse, emergence, rising, dominance, downturn, increasing,
# Nearest to notes: note, pages, articles, glossary, biographical, concise, typography, paper,
# Nearest to grand: duchy, brabant, prix, slam, tuscany, auto, dukes, rapids,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.4049 0.0420 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.3783 0.0414 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.4486 0.0404 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.4427 0.0405 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.3422 0.0408 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.4243 0.0405 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.3680 0.0403 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.4202 0.0405 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.3354 0.0400 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.3991 0.0406 sec/batch
# Nearest to between: both, resolve, difference, with, within, relationship, in, connection,
# Nearest to during: after, throughout, lasted, fifties, peloponnesian, saw, punic, ensuing,
# Nearest to see: list, references, links, topics, external, redirects, please, wikibooks,
# Nearest to who: whom, elders, whose, imprison, personally, gifted, scorn, bodyguards,
# Nearest to used: use, employed, using, uses, applied, intended, usage, coined,
# Nearest to d: b, politician, violinist, vasily, folklorist, neuroscientist, mineralogist, diarist,
# Nearest to or: usually, typically, either, omission, any, urinate, xylene, parsed,
# Nearest to b: d, politician, violinist, borisovich, orientalist, politican, ivanovich, mineralogist,
# Nearest to running: run, runs, ran, yards, drivers, road, bike, operating,
# Nearest to award: awards, nominations, bafta, oscar, grammy, emmy, nomination, oscars,
# Nearest to dr: dre, michael, seuss, wilkins, keith, harvey, murray, nancy,
# Nearest to marriage: divorce, marriages, wife, marry, married, daughter, illegitimate, adultery,
# Nearest to bill: clinton, ceo, congressman, kevin, carter, nixon, barry, hayes,
# Nearest to rise: decline, fall, dominance, emergence, collapse, rising, prominence, popularity,
# Nearest to notes: note, pages, section, entries, quotes, stein, lecture, detailed,
# Nearest to grand: prix, slam, duchy, auto, tuscany, knights, equestrian, rapids,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.4320 0.0416 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.3538 0.0405 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.2841 0.0408 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.4266 0.0406 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.4096 0.0407 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.4153 0.0403 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.4177 0.0406 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.4560 0.0405 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.3919 0.0407 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.3396 0.0408 sec/batch
# Nearest to between: both, with, difference, resolve, within, relationship, caucasoid, respectively,
# Nearest to during: lasted, after, throughout, peloponnesian, attrition, punic, ensuing, period,
# Nearest to see: list, references, external, topics, links, redirects, history, timeline,
# Nearest to who: whom, gifted, whose, elders, clan, forgiven, caste, assassins,
# Nearest to used: use, using, employed, uses, applied, referred, usage, referring,
# Nearest to d: b, ivoire, te, politician, sar, maybach, honneur, diarist,
# Nearest to or: usually, urinate, typically, themis, either, xylene, cheetah, stun,
# Nearest to b: d, politician, associativity, borisovich, f, coprime, isomorphism, xf,
# Nearest to running: run, runs, ran, bike, operating, drivers, platform, freeway,
# Nearest to award: awards, hugo, bafta, oscar, nominations, pulitzer, nebula, emmy,
# Nearest to dr: dre, michael, seuss, mr, harvey, gershwin, murray, harold,
# Nearest to marriage: divorce, marriages, wife, daughter, married, marry, divorced, husband,
# Nearest to bill: clinton, impeachment, veto, congressman, carter, impeached, senator, ceo,
# Nearest to rise: decline, fall, rising, dominance, emergence, collapse, migrations, dominated,
# Nearest to notes: note, section, quotes, pages, detailed, entries, concise, chords,
# Nearest to grand: auto, prix, slam, theft, duchy, knights, rapids, master,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.4508 0.0418 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.4085 0.0404 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.3943 0.0409 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.4064 0.0405 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.4046 0.0407 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.4113 0.0404 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.3902 0.0406 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.3428 0.0407 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.3500 0.0404 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.3630 0.0404 sec/batch
# Nearest to between: both, with, within, difference, respectively, relationship, in, resolve,
# Nearest to during: throughout, lasted, after, saw, period, late, before, postwar,
# Nearest to see: list, references, topics, external, links, redirects, timeline, history,
# Nearest to who: whom, elders, whose, clan, forgiven, partake, fellow, nizkor,
# Nearest to used: use, using, uses, employed, applied, intended, abbreviated, referred,
# Nearest to d: te, ivoire, b, ration, sar, supp, honneur, quelques,
# Nearest to or: usually, either, xylene, typically, passwords, any, specific, themis,
# Nearest to b: associativity, f, injective, coprime, nonzero, mathbb, modulo, satisfies,
# Nearest to running: run, ran, runs, drivers, operating, stretch, bike, platform,
# Nearest to award: awards, hugo, bafta, oscar, emmy, pulitzer, nominations, nebula,
# Nearest to dr: dre, michael, seuss, jeffrey, wilkins, gershwin, meyer, shapiro,
# Nearest to marriage: marriages, divorce, wife, marry, married, daughter, mother, illegitimate,
# Nearest to bill: clinton, bills, veto, legislation, impeachment, impeached, congressman, ceo,
# Nearest to rise: decline, emergence, fall, rising, dominance, popularity, collapse, migrations,
# Nearest to notes: note, chords, bass, section, pitch, string, octave, strings,
# Nearest to grand: slam, prix, auto, duchy, theft, knights, tuscany, duke,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.3873 0.0418 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.3799 0.0403 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.3477 0.0408 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.4040 0.0404 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.1208 0.0406 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.3314 0.0406 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.2529 0.0403 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.3747 0.0409 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.4014 0.0406 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.3911 0.0409 sec/batch
# Nearest to between: resolve, within, both, difference, ushering, with, relationship, connection,
# Nearest to during: lasted, throughout, after, saw, before, ensuing, fifties, postwar,
# Nearest to see: references, list, topics, external, links, redirects, timeline, history,
# Nearest to who: whom, whose, elders, forgiven, gifted, while, fellow, him,
# Nearest to used: use, using, employed, uses, applied, referring, coined, pejoratively,
# Nearest to d: b, politician, vasily, folklorist, anderssen, adventurer, diarist, baldassare,
# Nearest to or: usually, any, xylene, typically, either, exclusivity, urinate, person,
# Nearest to b: d, politican, politician, orientalist, adventurer, borisovich, statesman, mineralogist,
# Nearest to running: run, ran, runs, drivers, jumping, bike, backs, quarterbacks,
# Nearest to award: awards, hugo, bafta, grammy, emmy, oscar, pulitzer, oscars,
# Nearest to dr: dre, michael, wilkins, goldstein, seuss, egan, jekyll, griffiths,
# Nearest to marriage: marriages, divorce, marry, wife, daughter, married, adultery, child,
# Nearest to bill: clinton, congressman, bills, hillary, veto, impeached, impeachment, kevin,
# Nearest to rise: decline, fall, emergence, rising, dominance, collapse, popularity, migrations,
# Nearest to notes: note, chords, afterword, string, bass, chord, octave, quotation,
# Nearest to grand: prix, auto, slam, duchy, duchess, tuscany, knights, theft,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 4.4449 0.0418 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 4.4561 0.0407 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 4.4657 0.0409 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 4.4216 0.0405 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.3318 0.0403 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.3147 0.0405 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.4052 0.0404 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.3610 0.0404 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.3984 0.0400 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.4045 0.0402 sec/batch
# Nearest to between: difference, both, within, with, respectively, resolve, in, relationship,
# Nearest to during: lasted, throughout, after, saw, peloponnesian, edo, postwar, fifties,
# Nearest to see: list, references, links, external, topics, redirects, timeline, please,
# Nearest to who: whom, gifted, whose, elders, imprison, admire, clan, him,
# Nearest to used: use, using, uses, applied, employed, abbreviated, intended, generically,
# Nearest to d: b, te, ivoire, sar, folklorist, eb, diarist, anderssen,
# Nearest to or: usually, xylene, typically, specific, either, generically, urinate, parsed,
# Nearest to b: d, associativity, injective, f, nonzero, coprime, satisfies, xf,
# Nearest to running: run, runs, ran, drivers, operating, platform, cp, window,
# Nearest to award: awards, hugo, bafta, grammy, emmy, oscar, pulitzer, oscars,
# Nearest to dr: dre, michael, wilkins, goldstein, seuss, jekyll, griffith, hoffman,
# Nearest to marriage: divorce, marriages, marry, wife, daughter, married, divorced, child,
# Nearest to bill: clinton, bills, congressman, hillary, impeached, legislation, impeachment, veto,
# Nearest to rise: decline, fall, rising, emergence, dominance, collapse, migrations, prominence,
# Nearest to notes: note, section, bass, afterword, chords, quotes, chart, detailed,
# Nearest to grand: duchy, prix, slam, auto, duchess, tuscany, brabant, knights,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.3953 0.0418 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.3746 0.0403 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 4.1948 0.0404 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 4.2517 0.0407 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 4.3805 0.0407 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 4.2689 0.0405 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 4.3788 0.0406 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 4.3832 0.0408 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 4.3617 0.0405 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 4.3104 0.0402 sec/batch
# Nearest to between: both, difference, with, within, gap, in, resolve, connection,
# Nearest to during: after, lasted, throughout, before, postwar, late, saw, in,
# Nearest to see: list, references, links, external, topics, timeline, redirects, please,
# Nearest to who: whom, whose, gifted, fellow, elders, moabites, clan, scorn,
# Nearest to used: use, using, uses, employed, applied, intended, referred, coined,
# Nearest to d: b, vasily, politician, anderssen, alfons, sar, lebrun, diarist,
# Nearest to or: usually, xylene, typically, either, etc, rearden, specific, urinate,
# Nearest to b: d, politician, politican, orientalist, geologist, borisovich, mathematician, mineralogist,
# Nearest to running: run, ran, runs, operating, drivers, platform, emulation, gtk,
# Nearest to award: awards, bafta, grammy, emmy, hugo, oscars, oscar, pulitzer,
# Nearest to dr: dre, michael, goldstein, seuss, wilkins, jekyll, mr, griffith,
# Nearest to marriage: divorce, marriages, marry, wife, sexual, married, daughter, adultery,
# Nearest to bill: clinton, congressman, hillary, impeached, bills, impeachment, lewinsky, haley,
# Nearest to rise: decline, fall, dominance, rising, emergence, collapse, prominence, dominate,
# Nearest to notes: note, chords, bass, chord, pitch, octave, quotation, strings,
# Nearest to grand: duchy, prix, slam, auto, tuscany, brabant, duchess, dukes,
# Epoch 2/10 Iteration: 23100 Avg. Training loss: 4.3890 0.0418 sec/batch
# Epoch 2/10 Iteration: 23200 Avg. Training loss: 4.3752 0.0405 sec/batch
# Epoch 2/10 Iteration: 23300 Avg. Training loss: 4.4521 0.0402 sec/batch
# Epoch 3/10 Iteration: 23400 Avg. Training loss: 4.3926 0.0346 sec/batch
# Epoch 3/10 Iteration: 23500 Avg. Training loss: 4.3310 0.0403 sec/batch
# Epoch 3/10 Iteration: 23600 Avg. Training loss: 4.3799 0.0404 sec/batch
# Epoch 3/10 Iteration: 23700 Avg. Training loss: 4.3717 0.0406 sec/batch
# Epoch 3/10 Iteration: 23800 Avg. Training loss: 4.3661 0.0411 sec/batch
# Epoch 3/10 Iteration: 23900 Avg. Training loss: 4.3712 0.0404 sec/batch
# Epoch 3/10 Iteration: 24000 Avg. Training loss: 4.3295 0.0407 sec/batch
# Nearest to between: both, difference, with, within, relationship, resolve, incestuous, connection,
# Nearest to during: after, lasted, throughout, late, before, fifties, postwar, bloodiest,
# Nearest to see: references, list, links, external, timeline, redirects, topics, history,
# ...
# Epoch 10/10 Iteration: 109000 Avg. Training loss: 4.1985 0.0408 sec/batch
# Nearest to between: both, in, among, difference, within, with, differences, distinction,
# Nearest to during: after, throughout, when, prior, before, early, in, period,
# Nearest to see: list, external, links, references, topics, also, disambiguation, of,
# Nearest to who: whose, whom, but, while, that, which, he, and,
# Nearest to used: use, using, uses, referred, employed, applied, useful, called,
# Nearest to d: b, c, ivoire, g, abidjan, azur, te, globemaster,
# Nearest to or: usually, either, a, and, typically, sometimes, may, the,
# Nearest to b: d, c, f, p, globemaster, coprime, r, n,
# Nearest to running: run, runs, ran, executing, line, paced, stretches, woodhull,
# Nearest to award: awards, awarded, grammy, emmy, nomination, bafta, outstanding, hugo,
# Nearest to dr: dre, strangelove, frink, zhisui, professor, dobb, surgeon, jekyll,
# Nearest to marriage: marriages, divorce, marry, married, wife, polyamory, polygamy, spouses,
# Nearest to bill: bills, belichick, lading, moyers, clinton, oddie, kane, overrode,
# Nearest to rise: fall, access, emergence, decline, nationalism, collapse, rising, impression,
# Nearest to notes: note, issued, csli, banknotes, octave, harpists, paton, harmonics,
# Nearest to grand: prix, rapids, slam, eerdmans, jagie, masters, silberman, muscovy,
# Epoch 10/10 Iteration: 109100 Avg. Training loss: 4.2537 0.0416 sec/batch
# Epoch 10/10 Iteration: 109200 Avg. Training loss: 4.2212 0.0406 sec/batch
# Epoch 10/10 Iteration: 109300 Avg. Training loss: 4.1719 0.0404 sec/batch
# Epoch 10/10 Iteration: 109400 Avg. Training loss: 4.2112 0.0404 sec/batch
# Epoch 10/10 Iteration: 109500 Avg. Training loss: 4.1728 0.0404 sec/batch
# Epoch 10/10 Iteration: 109600 Avg. Training loss: 4.2374 0.0404 sec/batch
# Epoch 10/10 Iteration: 109700 Avg. Training loss: 4.2395 0.0404 sec/batch
# Epoch 10/10 Iteration: 109800 Avg. Training loss: 4.2585 0.0407 sec/batch
# Epoch 10/10 Iteration: 109900 Avg. Training loss: 4.2255 0.0409 sec/batch
# Epoch 10/10 Iteration: 110000 Avg. Training loss: 4.1487 0.0406 sec/batch
# Nearest to between: both, in, within, with, among, difference, differences, of,
# Nearest to during: after, prior, throughout, when, before, saw, in, early,
# Nearest to see: list, external, links, references, topics, disambiguation, also, article,
# Nearest to who: whose, whom, while, that, but, he, which, daleks,
# Nearest to used: use, using, uses, referred, employed, useful, applied, seen,
# Nearest to d: b, c, globemaster, politician, frederick, vallejo, abidjan, wolfenstein,
# Nearest to or: either, usually, any, a, and, typically, sometimes, may,
# Nearest to b: d, p, c, politician, f, one, composer, musician,
# Nearest to running: run, runs, ran, line, executing, paced, stretches, wilbert,
# Nearest to award: awards, awarded, nomination, grammy, emmy, medal, nominations, bafta,
# Nearest to dr: dre, seuss, krs, snoop, strangelove, zhisui, dobb, mabuse,
# Nearest to marriage: marriages, marry, married, divorce, wife, polyamory, daughter, divorced,
# Nearest to bill: bills, moyers, belichick, clinton, oddie, lading, kane, haley,
# Nearest to rise: fall, emergence, access, collapse, rising, decline, nationalism, rose,
# Nearest to notes: note, csli, issued, banknotes, pages, paton, references, lecture,
# Nearest to grand: prix, slam, rapids, eerdmans, knights, masters, jagie, fondation,
# Epoch 10/10 Iteration: 110100 Avg. Training loss: 4.2007 0.0417 sec/batch
# Epoch 10/10 Iteration: 110200 Avg. Training loss: 4.1362 0.0403 sec/batch
# Epoch 10/10 Iteration: 110300 Avg. Training loss: 4.2045 0.0404 sec/batch
# Epoch 10/10 Iteration: 110400 Avg. Training loss: 4.2294 0.0407 sec/batch
# Epoch 10/10 Iteration: 110500 Avg. Training loss: 4.1888 0.0405 sec/batch
# Epoch 10/10 Iteration: 110600 Avg. Training loss: 4.2430 0.0406 sec/batch
# Epoch 10/10 Iteration: 110700 Avg. Training loss: 4.2017 0.0405 sec/batch
# Epoch 10/10 Iteration: 110800 Avg. Training loss: 4.1735 0.0403 sec/batch
# Epoch 10/10 Iteration: 110900 Avg. Training loss: 4.2079 0.0407 sec/batch
# Epoch 10/10 Iteration: 111000 Avg. Training loss: 4.1517 0.0406 sec/batch
# Nearest to between: both, in, differences, with, difference, within, close, intra,
# Nearest to during: after, throughout, prior, when, before, saw, in, period,
# Nearest to see: list, external, links, references, topics, article, this, disambiguation,
# Nearest to who: whom, whose, while, that, but, which, young, he,
# Nearest to used: use, using, uses, referred, employed, useful, seen, applied,
# Nearest to d: b, one, eight, nine, three, politician, seven, six,
# Nearest to or: usually, either, sometimes, a, typically, and, etc, may,
# Nearest to b: d, one, musician, composer, politician, writer, actor, seven,
# Nearest to running: run, ran, runs, executing, line, stretches, goes, paced,
# Nearest to award: awards, awarded, nomination, grammy, emmy, bafta, nominations, oscar,
# Nearest to dr: dre, seuss, mathers, krs, snoop, eminem, mabuse, zhisui,
# Nearest to marriage: marriages, marry, married, divorce, wife, daughter, polyamory, divorced,
# Nearest to bill: bills, moyers, clinton, belichick, lading, kane, oddie, legislation,
# Nearest to rise: fall, access, decline, emergence, rising, collapse, impression, introduction,
# Nearest to notes: note, csli, issued, banknotes, volumes, kronor, pages, numismatics,
# Nearest to grand: prix, slam, constructors, rapids, masters, knights, imola, fondation,
# Epoch 10/10 Iteration: 111100 Avg. Training loss: 4.2546 0.0416 sec/batch
# Epoch 10/10 Iteration: 111200 Avg. Training loss: 4.0903 0.0400 sec/batch
# Epoch 10/10 Iteration: 111300 Avg. Training loss: 4.2077 0.0405 sec/batch
# Epoch 10/10 Iteration: 111400 Avg. Training loss: 4.2285 0.0405 sec/batch
# Epoch 10/10 Iteration: 111500 Avg. Training loss: 4.1975 0.0405 sec/batch
# Epoch 10/10 Iteration: 111600 Avg. Training loss: 4.0291 0.0407 sec/batch
# Epoch 10/10 Iteration: 111700 Avg. Training loss: 4.2510 0.0408 sec/batch
# Epoch 10/10 Iteration: 111800 Avg. Training loss: 4.2348 0.0407 sec/batch
# Epoch 10/10 Iteration: 111900 Avg. Training loss: 4.1925 0.0406 sec/batch
# Epoch 10/10 Iteration: 112000 Avg. Training loss: 4.2505 0.0407 sec/batch
# Nearest to between: both, in, differences, difference, with, within, vs, some,
# Nearest to during: after, throughout, prior, when, in, period, before, saw,
# Nearest to see: list, external, references, links, topics, article, disambiguation, redirects,
# Nearest to who: whom, whose, while, but, young, that, which, although,
# Nearest to used: use, using, uses, referred, employed, useful, applied, seen,
# Nearest to d: b, globemaster, c, ivoire, cxd, schadeberg, abidjan, azur,
# Nearest to or: usually, either, sometimes, typically, a, and, often, are,
# Nearest to b: d, f, c, allegri, p, globemaster, coprime, northrop,
# Nearest to running: run, runs, ran, goes, stretches, woodhull, line, executing,
# Nearest to award: awards, awarded, grammy, nomination, emmy, bafta, nominations, medal,
# Nearest to dr: dre, seuss, mathers, snoop, eminem, krs, dobb, mabuse,
# Nearest to marriage: marriages, marry, married, divorce, daughter, wife, polyamory, betrothed,
# Nearest to bill: clinton, bills, belichick, carter, moyers, lading, rodham, reagan,
# Nearest to rise: fall, rising, decline, emergence, collapse, access, impression, increased,
# Nearest to notes: note, csli, issued, pages, banknotes, volumes, inversions, paton,
# Nearest to grand: prix, masters, knights, slam, constructors, rapids, fondation, freemason,
# Epoch 10/10 Iteration: 112100 Avg. Training loss: 4.2602 0.0417 sec/batch
# Epoch 10/10 Iteration: 112200 Avg. Training loss: 4.1793 0.0407 sec/batch
# Epoch 10/10 Iteration: 112300 Avg. Training loss: 4.1719 0.0408 sec/batch
# Epoch 10/10 Iteration: 112400 Avg. Training loss: 4.2551 0.0406 sec/batch
# Epoch 10/10 Iteration: 112500 Avg. Training loss: 4.2331 0.0408 sec/batch
# Epoch 10/10 Iteration: 112600 Avg. Training loss: 4.2110 0.0406 sec/batch
# Epoch 10/10 Iteration: 112700 Avg. Training loss: 4.2298 0.0407 sec/batch
# Epoch 10/10 Iteration: 112800 Avg. Training loss: 4.2176 0.0406 sec/batch
# Epoch 10/10 Iteration: 112900 Avg. Training loss: 4.2435 0.0408 sec/batch
# Epoch 10/10 Iteration: 113000 Avg. Training loss: 4.1934 0.0406 sec/batch
# Nearest to between: both, in, with, differences, within, among, vs, that,
# Nearest to during: after, throughout, in, prior, the, when, saw, before,
# Nearest to see: list, references, external, links, topics, the, also, article,
# Nearest to who: whom, whose, while, that, but, and, which, although,
# Nearest to used: use, using, uses, referred, employed, useful, applied, called,
# Nearest to d: b, c, e, globemaster, g, ivoire, azur, cxd,
# Nearest to or: usually, either, sometimes, often, typically, a, may, and,
# Nearest to b: d, f, c, p, globemaster, northrop, allegri, e,
# Nearest to running: run, runs, ran, stretches, goes, executing, paced, line,
# Nearest to award: awards, awarded, emmy, grammy, hugo, bafta, novelette, nomination,
# Nearest to dr: dre, seuss, krs, mabuse, mathers, snoop, dobb, eminem,
# Nearest to marriage: marriages, marry, married, divorce, wife, daughter, polyamory, betrothed,
# Nearest to bill: bills, lading, legislation, house, overridden, clinton, overrode, rajya,
# Nearest to rise: fall, emergence, decline, rising, access, collapse, impression, nationalism,
# Nearest to notes: note, harmonics, octave, inversions, mixolydian, pitch, chord, diatonic,
# Nearest to grand: prix, knights, masters, constructors, slam, templar, freemason, fondation,
# Epoch 10/10 Iteration: 113100 Avg. Training loss: 4.1006 0.0416 sec/batch
# Epoch 10/10 Iteration: 113200 Avg. Training loss: 4.1979 0.0407 sec/batch
# Epoch 10/10 Iteration: 113300 Avg. Training loss: 4.1778 0.0403 sec/batch
# Epoch 10/10 Iteration: 113400 Avg. Training loss: 4.1875 0.0404 sec/batch
# Epoch 10/10 Iteration: 113500 Avg. Training loss: 4.1870 0.0407 sec/batch
# Epoch 10/10 Iteration: 113600 Avg. Training loss: 4.2241 0.0405 sec/batch
# Epoch 10/10 Iteration: 113700 Avg. Training loss: 4.1947 0.0407 sec/batch
# Epoch 10/10 Iteration: 113800 Avg. Training loss: 3.8955 0.0400 sec/batch
# Epoch 10/10 Iteration: 113900 Avg. Training loss: 4.0604 0.0410 sec/batch
# Epoch 10/10 Iteration: 114000 Avg. Training loss: 4.1271 0.0411 sec/batch
# Nearest to between: both, in, with, within, differences, among, vs, difference,
# Nearest to during: after, throughout, in, when, before, the, prior, period,
# Nearest to see: list, references, external, links, topics, article, the, this,
# Nearest to who: whose, whom, while, that, but, which, and, when,
# Nearest to used: use, using, referred, uses, employed, applied, seen, useful,
# Nearest to d: b, one, three, nine, eight, four, seven, five,
# Nearest to or: either, usually, sometimes, and, a, any, typically, may,
# Nearest to b: d, one, eight, four, seven, three, six, five,
# Nearest to running: run, runs, ran, line, stretches, executing, goes, term,
# Nearest to award: awards, emmy, nomination, awarded, hugo, novelette, medal, bafta,
# Nearest to dr: dre, seuss, krs, mathers, mahoney, dobb, snoop, crooks,
# Nearest to marriage: marriages, marry, married, daughter, wife, divorce, polyamory, divorced,
# Nearest to bill: bills, clinton, legislation, belichick, moyers, overridden, campaign, carter,
# Nearest to rise: fall, decline, rising, emergence, access, collapse, impression, nationalism,
# Nearest to notes: note, inversions, csli, issued, paton, links, harmonics, references,
# Nearest to grand: prix, knights, constructors, freemason, masters, rapids, templar, slam,
# Epoch 10/10 Iteration: 114100 Avg. Training loss: 4.2068 0.0417 sec/batch
# Epoch 10/10 Iteration: 114200 Avg. Training loss: 4.2280 0.0404 sec/batch
# Epoch 10/10 Iteration: 114300 Avg. Training loss: 4.2143 0.0407 sec/batch
# Epoch 10/10 Iteration: 114400 Avg. Training loss: 4.2795 0.0409 sec/batch
# Epoch 10/10 Iteration: 114500 Avg. Training loss: 4.2695 0.0406 sec/batch
# Epoch 10/10 Iteration: 114600 Avg. Training loss: 4.2748 0.0404 sec/batch
# Epoch 10/10 Iteration: 114700 Avg. Training loss: 4.2330 0.0406 sec/batch
# Epoch 10/10 Iteration: 114800 Avg. Training loss: 4.0605 0.0405 sec/batch
# Epoch 10/10 Iteration: 114900 Avg. Training loss: 4.1941 0.0406 sec/batch
# Epoch 10/10 Iteration: 115000 Avg. Training loss: 4.2139 0.0405 sec/batch
# Nearest to between: both, in, with, within, among, difference, differences, some,
# Nearest to during: after, throughout, in, prior, when, period, before, war,
# Nearest to see: list, references, external, links, topics, article, disambiguation, the,
# Nearest to who: whom, whose, while, but, young, that, which, said,
# Nearest to used: use, using, uses, referred, employed, applied, useful, seen,
# Nearest to d: b, c, corr, g, globemaster, e, vil, azur,
# Nearest to or: either, usually, typically, sometimes, a, any, often, are,
# Nearest to b: d, f, c, e, p, allegri, ddo, globemaster,
# Nearest to running: run, runs, ran, stretches, wilbert, line, executing, woodhull,
# Nearest to award: awards, emmy, awarded, grammy, nomination, bafta, medal, hugo,
# Nearest to dr: dre, seuss, mathers, krs, snoop, mahoney, meanwhile, crooks,
# Nearest to marriage: marriages, marry, married, divorce, daughter, wife, polyamory, wedding,
# Nearest to bill: bills, moyers, clinton, legislation, belichick, oddie, overrode, overridden,
# Nearest to rise: fall, emergence, collapse, access, rising, decline, nationalism, rose,
# Nearest to notes: note, issued, csli, volumes, references, links, inversions, paton,
# Nearest to grand: prix, knights, jagie, slam, constructors, masters, freemason, fondation,
# Epoch 10/10 Iteration: 115100 Avg. Training loss: 4.1586 0.0416 sec/batch
# Epoch 10/10 Iteration: 115200 Avg. Training loss: 4.1951 0.0405 sec/batch
# Epoch 10/10 Iteration: 115300 Avg. Training loss: 4.2498 0.0406 sec/batch
# Epoch 10/10 Iteration: 115400 Avg. Training loss: 4.1827 0.0405 sec/batch
# Epoch 10/10 Iteration: 115500 Avg. Training loss: 4.1888 0.0406 sec/batch
# Epoch 10/10 Iteration: 115600 Avg. Training loss: 3.9896 0.0405 sec/batch
# Epoch 10/10 Iteration: 115700 Avg. Training loss: 4.1458 0.0406 sec/batch
# Epoch 10/10 Iteration: 115800 Avg. Training loss: 4.2183 0.0409 sec/batch
# Epoch 10/10 Iteration: 115900 Avg. Training loss: 4.0937 0.0408 sec/batch
# Epoch 10/10 Iteration: 116000 Avg. Training loss: 4.2219 0.0409 sec/batch
# Nearest to between: both, in, with, within, difference, differences, among, close,
# Nearest to during: after, prior, throughout, when, before, in, period, ended,
# Nearest to see: list, references, external, links, topics, redirects, article, timeline,
# Nearest to who: whose, whom, while, which, that, but, young, however,
# Nearest to used: use, using, uses, referred, useful, employed, applied, called,
# Nearest to d: b, one, politician, composer, four, c, musician, three,
# Nearest to or: either, usually, sometimes, typically, a, and, are, often,
# Nearest to b: d, composer, one, politician, seven, writer, musician, singer,
# Nearest to running: run, runs, ran, stretches, line, wilbert, goes, woodhull,
# Nearest to award: awards, nomination, emmy, grammy, bafta, nominations, filmfare, awarded,
# Nearest to dr: dre, seuss, krs, mathers, snoop, zhisui, mahoney, strangelove,
# Nearest to marriage: marriages, marry, divorce, married, wife, daughter, relationship, polyamory,
# Nearest to bill: bills, legislation, belichick, moyers, oddie, clinton, lading, haley,
# Nearest to rise: fall, emergence, decline, access, collapse, rising, nationalism, predominance,
# Nearest to notes: note, csli, issued, reports, numismatics, pages, paton, volumes,
# Nearest to grand: prix, slam, masters, constructors, rapids, eerdmans, jagie, slotted,
# Epoch 10/10 Iteration: 116100 Avg. Training loss: 4.1949 0.0416 sec/batch
# Epoch 10/10 Iteration: 116200 Avg. Training loss: 4.1990 0.0408 sec/batch
# Epoch 10/10 Iteration: 116300 Avg. Training loss: 4.1968 0.0413 sec/batch
# Epoch 10/10 Iteration: 116400 Avg. Training loss: 4.2047 0.0410 sec/batch
# Epoch 10/10 Iteration: 116500 Avg. Training loss: 4.2426 0.0407 sec/batch
# Epoch 10/10 Iteration: 116600 Avg. Training loss: 4.2647 0.0407 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
